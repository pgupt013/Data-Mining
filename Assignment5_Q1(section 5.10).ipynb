# %%
# Import the libraries
import pandas as pd
from mlxtend.preprocessing import OnehotTransactions
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules

# %%
# data of transaction for market analysis
dataset = [['Bread', 'Milk'],
           ['Bread', 'Diapers', 'Beer', 'Eggs'],
           ['Milk', 'Diapers', 'Beer', 'Cola'],
           ['Bread', 'Milk', 'Diapers', 'Beer'],
           ['Bread', 'Milk', 'Diapers', 'Cola']     
          ]
dataset
# Out:
# [['Bread', 'Milk'],
#  ['Bread', 'Diapers', 'Beer', 'Eggs'],
#  ['Milk', 'Diapers', 'Beer', 'Cola'],
#  ['Bread', 'Milk', 'Diapers', 'Beer'],
#  ['Bread', 'Milk', 'Diapers', 'Cola']]

# %%
# Translate the data into 0 or 1 form
#oht = OnehotTransactions()
oht = TransactionEncoder()
oht_array = oht.fit(dataset).transform(dataset)
df = pd.DataFrame(oht_array, columns=oht.columns_).astype("int")
df[:5]
# Out:
#    Beer  Bread  Cola  Diapers  Eggs  Milk
# 0     0      1     0        0     0     1
# 1     1      1     0        1     1     0
# 2     1      0     1        1     0     1
# 3     1      1     0        1     0     1
# 4     0      1     1        1     0     1

# %%
# Calculate the support for the itemsets
frequent_itemsets= apriori(df, min_support=0.2,use_colnames=True)
frequent_itemsets[:5]
# Out:
#    support   itemsets
# 0      0.6     (Beer)
# 1      0.8    (Bread)
# 2      0.4     (Cola)
# 3      0.8  (Diapers)
# 4      0.2     (Eggs)

# %%
frequent_itemsets['length']=frequent_itemsets['itemsets'].apply(lambda x:len(x))
frequent_itemsets[:2]
#print(apriori(df, min_support=0.1, use_colnames=True))
#frequent_itemsets.info()
# Out:
#    support itemsets  length
# 0      0.6   (Beer)       1
# 1      0.8  (Bread)       1

# %% [markdown]
# ### 1. A rule that has high support and high confidence.

# %%
frequent_itemsets= apriori(df, min_support=0.6,use_colnames=True)
frequent_itemsets
# Out:
#    support          itemsets
# 0      0.6            (Beer)
# 1      0.8           (Bread)
# 2      0.8         (Diapers)
# 3      0.8            (Milk)
# 4      0.6   (Diapers, Beer)
# 5      0.6  (Diapers, Bread)
# 6      0.6     (Bread, Milk)
# 7      0.6   (Diapers, Milk)

# %%
rule_confidence=association_rules(frequent_itemsets, metric="confidence", min_threshold=.75)
rule_confidence
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (Beer)   (Diapers)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf

# %% [markdown]
# ### 2. A rule that has reasonably high support but low confidence.

# %%
# In this case used minimum support 0.6 and threshold confidence 0.1 
frequent_itemsets= apriori(df, min_support=0.6,use_colnames=True)
frequent_itemsets

rule_confidence=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.25)
rule_confidence
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0   (Diapers)      (Beer)                 0.8                 0.6      0.6
# 1      (Beer)   (Diapers)                 0.6                 0.8      0.6
# 2   (Diapers)     (Bread)                 0.8                 0.8      0.6
# 3     (Bread)   (Diapers)                 0.8                 0.8      0.6
# 4     (Bread)      (Milk)                 0.8                 0.8      0.6
# 5      (Milk)     (Bread)                 0.8                 0.8      0.6
# 6   (Diapers)      (Milk)                 0.8                 0.8      0.6
# 7      (Milk)   (Diapers)                 0.8                 0.8      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  1.2500      0.12         1.6
# 1        1.00  1.2500      0.12         inf
# 2        0.75  0.9375     -0.04         0.8
# 3        0.75  0.9375     -0.04         0.8
# 4        0.75  0.9375     -0.04         0.8
# 5        0.75  0.9375     -0.04         0.8
# 6        0.75  0.9375     -0.04         0.8
# 7        0.75  0.9375     -0.04         0.8

# %% [markdown]
# ### 3. A rule that has low support and low confidence.

# %%
# In this case used minimum support 0.1 and threshold confidence 0.1 
frequent_itemsets= apriori(df, min_support=0.2,use_colnames=True)
frequent_itemsets
rule_confidence=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.25)
rule_confidence
# Out:
#                 antecedents             consequents  antecedent support  \
# 0                   (Bread)                  (Beer)                 0.8
# 1                    (Beer)                 (Bread)                 0.6
# 2                    (Cola)                  (Beer)                 0.4
# 3                    (Beer)                  (Cola)                 0.6
# 4                 (Diapers)                  (Beer)                 0.8
# 5                    (Beer)               (Diapers)                 0.6
# 6                    (Eggs)                  (Beer)                 0.2
# 7                    (Beer)                  (Eggs)                 0.6
# 8                    (Milk)                  (Beer)                 0.8
# 9                    (Beer)                  (Milk)                 0.6
# 10                  (Bread)                  (Cola)                 0.8
# 11                   (Cola)                 (Bread)                 0.4
# 12                (Diapers)                 (Bread)                 0.8
# 13                  (Bread)               (Diapers)                 0.8
# 14                   (Eggs)                 (Bread)                 0.2
# 15                  (Bread)                  (Eggs)                 0.8
# 16                  (Bread)                  (Milk)                 0.8
# 17                   (Milk)                 (Bread)                 0.8
# 18                (Diapers)                  (Cola)                 0.8
# 19                   (Cola)               (Diapers)                 0.4
# 20                   (Milk)                  (Cola)                 0.8
# 21                   (Cola)                  (Milk)                 0.4
# 22                   (Eggs)               (Diapers)                 0.2
# 23                (Diapers)                  (Eggs)                 0.8
# 24                (Diapers)                  (Milk)                 0.8
# 25                   (Milk)               (Diapers)                 0.8
# 26         (Diapers, Bread)                  (Beer)                 0.6
# 27          (Diapers, Beer)                 (Bread)                 0.6
# 28            (Bread, Beer)               (Diapers)                 0.4
# 29                (Diapers)           (Bread, Beer)                 0.8
# ..                      ...                     ...                 ...
# 124                  (Milk)  (Diapers, Bread, Beer)                 0.8
# 125                  (Beer)  (Diapers, Bread, Milk)                 0.6
# 126   (Diapers, Milk, Cola)                  (Beer)                 0.4
# 127   (Diapers, Milk, Beer)                  (Cola)                 0.4
# 128   (Diapers, Cola, Beer)                  (Milk)                 0.2
# 129      (Milk, Cola, Beer)               (Diapers)                 0.2
# 130         (Diapers, Milk)            (Cola, Beer)                 0.6
# 131         (Diapers, Cola)            (Milk, Beer)                 0.4
# 132         (Diapers, Beer)            (Milk, Cola)                 0.6
# 133            (Milk, Cola)         (Diapers, Beer)                 0.4
# 134            (Milk, Beer)         (Diapers, Cola)                 0.4
# 135            (Cola, Beer)         (Diapers, Milk)                 0.2
# 136               (Diapers)      (Milk, Cola, Beer)                 0.8
# 137                  (Milk)   (Diapers, Cola, Beer)                 0.8
# 138                  (Cola)   (Diapers, Milk, Beer)                 0.4
# 139                  (Beer)   (Diapers, Milk, Cola)                 0.6
# 140  (Diapers, Bread, Milk)                  (Cola)                 0.4
# 141  (Diapers, Bread, Cola)                  (Milk)                 0.2
# 142   (Diapers, Milk, Cola)                 (Bread)                 0.4
# 143     (Bread, Milk, Cola)               (Diapers)                 0.2
# 144        (Diapers, Bread)            (Milk, Cola)                 0.6
# 145         (Diapers, Milk)           (Bread, Cola)                 0.6
# 146         (Diapers, Cola)           (Bread, Milk)                 0.4
# 147           (Bread, Milk)         (Diapers, Cola)                 0.6
# 148           (Bread, Cola)         (Diapers, Milk)                 0.2
# 149            (Milk, Cola)        (Diapers, Bread)                 0.4
# 150               (Diapers)     (Bread, Milk, Cola)                 0.8
# 151                 (Bread)   (Diapers, Milk, Cola)                 0.8
# 152                  (Milk)  (Diapers, Bread, Cola)                 0.8
# 153                  (Cola)  (Diapers, Bread, Milk)                 0.4
#
#      consequent support  support  confidence      lift  leverage  conviction
# 0                   0.6      0.4    0.500000  0.833333     -0.08    0.800000
# 1                   0.8      0.4    0.666667  0.833333     -0.08    0.600000
# 2                   0.6      0.2    0.500000  0.833333     -0.04    0.800000
# 3                   0.4      0.2    0.333333  0.833333     -0.04    0.900000
# 4                   0.6      0.6    0.750000  1.250000      0.12    1.600000
# 5                   0.8      0.6    1.000000  1.250000      0.12         inf
# 6                   0.6      0.2    1.000000  1.666667      0.08         inf
# 7                   0.2      0.2    0.333333  1.666667      0.08    1.200000
# 8                   0.6      0.4    0.500000  0.833333     -0.08    0.800000
# 9                   0.8      0.4    0.666667  0.833333     -0.08    0.600000
# 10                  0.4      0.2    0.250000  0.625000     -0.12    0.800000
# 11                  0.8      0.2    0.500000  0.625000     -0.12    0.400000
# 12                  0.8      0.6    0.750000  0.937500     -0.04    0.800000
# 13                  0.8      0.6    0.750000  0.937500     -0.04    0.800000
# 14                  0.8      0.2    1.000000  1.250000      0.04         inf
# 15                  0.2      0.2    0.250000  1.250000      0.04    1.066667
# 16                  0.8      0.6    0.750000  0.937500     -0.04    0.800000
# 17                  0.8      0.6    0.750000  0.937500     -0.04    0.800000
# 18                  0.4      0.4    0.500000  1.250000      0.08    1.200000
# 19                  0.8      0.4    1.000000  1.250000      0.08         inf
# 20                  0.4      0.4    0.500000  1.250000      0.08    1.200000
# 21                  0.8      0.4    1.000000  1.250000      0.08         inf
# 22                  0.8      0.2    1.000000  1.250000      0.04         inf
# 23                  0.2      0.2    0.250000  1.250000      0.04    1.066667
# 24                  0.8      0.6    0.750000  0.937500     -0.04    0.800000
# 25                  0.8      0.6    0.750000  0.937500     -0.04    0.800000
# 26                  0.6      0.4    0.666667  1.111111      0.04    1.200000
# 27                  0.8      0.4    0.666667  0.833333     -0.08    0.600000
# 28                  0.8      0.4    1.000000  1.250000      0.08         inf
# 29                  0.4      0.4    0.500000  1.250000      0.08    1.200000
# ..                  ...      ...         ...       ...       ...         ...
# 124                 0.4      0.2    0.250000  0.625000     -0.12    0.800000
# 125                 0.4      0.2    0.333333  0.833333     -0.04    0.900000
# 126                 0.6      0.2    0.500000  0.833333     -0.04    0.800000
# 127                 0.4      0.2    0.500000  1.250000      0.04    1.200000
# 128                 0.8      0.2    1.000000  1.250000      0.04         inf
# 129                 0.8      0.2    1.000000  1.250000      0.04         inf
# 130                 0.2      0.2    0.333333  1.666667      0.08    1.200000
# 131                 0.4      0.2    0.500000  1.250000      0.04    1.200000
# 132                 0.4      0.2    0.333333  0.833333     -0.04    0.900000
# 133                 0.6      0.2    0.500000  0.833333     -0.04    0.800000
# 134                 0.4      0.2    0.500000  1.250000      0.04    1.200000
# 135                 0.6      0.2    1.000000  1.666667      0.08         inf
# 136                 0.2      0.2    0.250000  1.250000      0.04    1.066667
# 137                 0.2      0.2    0.250000  1.250000      0.04    1.066667
# 138                 0.4      0.2    0.500000  1.250000      0.04    1.200000
# 139                 0.4      0.2    0.333333  0.833333     -0.04    0.900000
# 140                 0.4      0.2    0.500000  1.250000      0.04    1.200000
# 141                 0.8      0.2    1.000000  1.250000      0.04         inf
# 142                 0.8      0.2    0.500000  0.625000     -0.12    0.400000
# 143                 0.8      0.2    1.000000  1.250000      0.04         inf
# 144                 0.4      0.2    0.333333  0.833333     -0.04    0.900000
# 145                 0.2      0.2    0.333333  1.666667      0.08    1.200000
# 146                 0.6      0.2    0.500000  0.833333     -0.04    0.800000
# 147                 0.4      0.2    0.333333  0.833333     -0.04    0.900000
# 148                 0.6      0.2    1.000000  1.666667      0.08         inf
# 149                 0.6      0.2    0.500000  0.833333     -0.04    0.800000
# 150                 0.2      0.2    0.250000  1.250000      0.04    1.066667
# 151                 0.4      0.2    0.250000  0.625000     -0.12    0.800000
# 152                 0.2      0.2    0.250000  1.250000      0.04    1.066667
# 153                 0.4      0.2    0.500000  1.250000      0.04    1.200000
#
# [154 rows x 9 columns]

# %%
rule_confidence['antecedents_len']=rule_confidence['antecedents'].apply(lambda x:len(x))
rule_confidence[(rule_confidence['antecedents_len']==1)& (rule_confidence['support']==0.2)&(rule_confidence['confidence']==0.25)]
# Out:
#     antecedents             consequents  antecedent support  \
# 10      (Bread)                  (Cola)                 0.8
# 15      (Bread)                  (Eggs)                 0.8
# 23    (Diapers)                  (Eggs)                 0.8
# 36      (Bread)            (Eggs, Beer)                 0.8
# 41      (Bread)            (Milk, Beer)                 0.8
# 42       (Milk)           (Bread, Beer)                 0.8
# 47    (Diapers)            (Cola, Beer)                 0.8
# 53       (Milk)            (Cola, Beer)                 0.8
# 60    (Diapers)            (Eggs, Beer)                 0.8
# 71    (Diapers)           (Bread, Cola)                 0.8
# 72      (Bread)         (Diapers, Cola)                 0.8
# 77      (Bread)            (Milk, Cola)                 0.8
# 78       (Milk)           (Bread, Cola)                 0.8
# 84    (Diapers)           (Eggs, Bread)                 0.8
# 85      (Bread)         (Eggs, Diapers)                 0.8
# 109   (Diapers)     (Eggs, Bread, Beer)                 0.8
# 110     (Bread)   (Eggs, Diapers, Beer)                 0.8
# 122   (Diapers)     (Bread, Milk, Beer)                 0.8
# 123     (Bread)   (Diapers, Milk, Beer)                 0.8
# 124      (Milk)  (Diapers, Bread, Beer)                 0.8
# 136   (Diapers)      (Milk, Cola, Beer)                 0.8
# 137      (Milk)   (Diapers, Cola, Beer)                 0.8
# 150   (Diapers)     (Bread, Milk, Cola)                 0.8
# 151     (Bread)   (Diapers, Milk, Cola)                 0.8
# 152      (Milk)  (Diapers, Bread, Cola)                 0.8
#
#      consequent support  support  confidence   lift  leverage  conviction  \
# 10                  0.4      0.2        0.25  0.625     -0.12    0.800000
# 15                  0.2      0.2        0.25  1.250      0.04    1.066667
# 23                  0.2      0.2        0.25  1.250      0.04    1.066667
# 36                  0.2      0.2        0.25  1.250      0.04    1.066667
# 41                  0.4      0.2        0.25  0.625     -0.12    0.800000
# 42                  0.4      0.2        0.25  0.625     -0.12    0.800000
# 47                  0.2      0.2        0.25  1.250      0.04    1.066667
# 53                  0.2      0.2        0.25  1.250      0.04    1.066667
# 60                  0.2      0.2        0.25  1.250      0.04    1.066667
# 71                  0.2      0.2        0.25  1.250      0.04    1.066667
# 72                  0.4      0.2        0.25  0.625     -0.12    0.800000
# 77                  0.4      0.2        0.25  0.625     -0.12    0.800000
# 78                  0.2      0.2        0.25  1.250      0.04    1.066667
# 84                  0.2      0.2        0.25  1.250      0.04    1.066667
# 85                  0.2      0.2        0.25  1.250      0.04    1.066667
# 109                 0.2      0.2        0.25  1.250      0.04    1.066667
# 110                 0.2      0.2        0.25  1.250      0.04    1.066667
# 122                 0.2      0.2        0.25  1.250      0.04    1.066667
# 123                 0.4      0.2        0.25  0.625     -0.12    0.800000
# 124                 0.4      0.2        0.25  0.625     -0.12    0.800000
# 136                 0.2      0.2        0.25  1.250      0.04    1.066667
# 137                 0.2      0.2        0.25  1.250      0.04    1.066667
# 150                 0.2      0.2        0.25  1.250      0.04    1.066667
# 151                 0.4      0.2        0.25  0.625     -0.12    0.800000
# 152                 0.2      0.2        0.25  1.250      0.04    1.066667
#
#      antecedents_len
# 10                 1
# 15                 1
# 23                 1
# 36                 1
# 41                 1
# 42                 1
# 47                 1
# 53                 1
# 60                 1
# 71                 1
# 72                 1
# 77                 1
# 78                 1
# 84                 1
# 85                 1
# 109                1
# 110                1
# 122                1
# 123                1
# 124                1
# 136                1
# 137                1
# 150                1
# 151                1
# 152                1

# %% [markdown]
# ### 4. A rule that has low support and high confidence.

# %%
# In this case used minimum support 0.1 and threshold confidence 0.8 
frequent_itemsets= apriori(df, min_support=0.2,use_colnames=True)
frequent_itemsets

rule_confidence=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.75)
rule_confidence[:5]
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (Beer)   (Diapers)                 0.6                 0.8      0.6
# 1      (Eggs)      (Beer)                 0.2                 0.6      0.2
# 2      (Eggs)     (Bread)                 0.2                 0.8      0.2
# 3      (Cola)   (Diapers)                 0.4                 0.8      0.4
# 4      (Cola)      (Milk)                 0.4                 0.8      0.4
#
#    confidence      lift  leverage  conviction
# 0         1.0  1.250000      0.12         inf
# 1         1.0  1.666667      0.08         inf
# 2         1.0  1.250000      0.04         inf
# 3         1.0  1.250000      0.08         inf
# 4         1.0  1.250000      0.08         inf
